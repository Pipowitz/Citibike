# %% [markdown]
# **Functions meant to find the best ML model for categorizing the customers and subscribers of the citibike data**

# %%
import numpy as np
import pandas as pd
from time import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# load the preprocessed dfs
df_ny=pd.read_pickle("./df_ny_pre.pkl")
df_jc=pd.read_pickle("./df_jc_pre.pkl")

# %%
def min_man_scal(df):
    """
    Min max scales the age and tripduration columns
    
    inputs:
      - df: a pandas dataframe
      
    returns:
      - df: a pandas dataframe
    """
    scaler = MinMaxScaler()
    feat_scal=["age", "tripduration"]
    df[feat_scal] = scaler.fit_transform(df[feat_scal])
    
    return df

# %%
# use the min_max scaler
df_jc=min_man_scal(df_jc)
df_ny=min_man_scal(df_ny)

# %%
# calculate the naive scores
accuracy, fscore=calculate_naive(target_jc)
accuracy_ny, fscore_ny=calculate_naive(target_ny)
# Out:
# Naive Predictor: [Accuracy score: 0.9374, F-score: 0.9493]
# Naive Predictor: [Accuracy score: 0.8899, F-score: 0.9099]

# %%
def calculate_naive(target):
    """
    Calculate the naive accuracy and fscore
    Pretend that all rides have been made by subscribers
    
    inputs:
      - target: the target series
      
    returns:
        - accuracy: the naive accuracy score
        - fscore: the naive fscore
    """
    # get the number of subscribers, customers and the total number of records
    n_sub=target.value_counts()[1]
    n_cust=target.value_counts()[0]
    n_records=n_sub+n_cust
    
    # calculate the values with the naive guess that all rides had been
    # done by customers
    accuracy = n_sub/n_records
    recall = n_sub/n_sub
    precision = n_sub/n_records

    # Calculate the fscore for beta 0.5
    fscore = (1+0.5**2)*precision*recall/((0.5**2*precision)+recall)

    # Print the results 
    print("Naive Predictor: [Accuracy score: {:.4f}, F-score: {:.4f}]".format(accuracy, fscore))#
    
    return accuracy, fscore

# %%
# separate target and features for both dataframes
target_jc = df_jc["usertype"]
feature_jc=df_jc.drop("usertype", axis=1)
target_ny = df_ny["usertype"]
feature_ny=df_ny.drop("usertype", axis=1)

# %%
X_train_jc, X_test_jc, y_train_jc, y_test_jc = train_test_split(feature_jc, 
                                                    target_jc, 
                                                    test_size = 0.2, 
                                                    random_state = 0)

# %%
X_train_ny, X_test_ny, y_train_ny, y_test_ny = train_test_split(feature_ny, 
                                                    target_ny, 
                                                    test_size = 0.2, 
                                                    random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

#Initialize the models
clf_A = GaussianNB()
clf_B = SVC(random_state=6)
clf_C = RandomForestClassifier(random_state=25)

results=get_results(clf_A, clf_B, clf_C, X_train_jc, y_train_jc, X_test_jc, y_test_jc)

# Run metrics visualization for the three supervised learning models chosen
evaluate(results, accuracy, fscore)
# Out:
# GaussianNB trained on 3538 samples.
# GaussianNB trained on 35389 samples.
# GaussianNB trained on 353892 samples.
# SVC trained on 3538 samples.
# SVC trained on 35389 samples.
# SVC trained on 353892 samples.
# RandomForestClassifier trained on 3538 samples.
# RandomForestClassifier trained on 35389 samples.
# RandomForestClassifier trained on 353892 samples.
# C:\Users\PPawelec\AppData\Local\Temp\ipykernel_11568\1375473375.py:68: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
def get_results(clf_A, clf_B, clf_C, X_train, y_train, X_test, y_test):
    """
    train and predict while looping through three models
    
    inputs:
      - clf_A: the first model
      - clf_A: the second model
      - clf_A: the third model
      - X_train: features training set
      - y_train: user type training set
      - X_test: features testing set
      - y_test: user type testing set
    """
    samples_100 = n_records
    samples_10 = int(n_records/10)
    samples_1 = int(n_records/100)

    # Collect results on the learners
    results = {}
    for clf in [clf_A, clf_B, clf_C]:
        clf_name = clf.__class__.__name__
        results[clf_name] = {}
        for i, samples in enumerate([samples_1, samples_10, samples_100]):
            results[clf_name][i] = \
            train_predict(clf, samples, X_train, y_train, X_test, y_test)
    return results

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier

#Initialize the models
clf_A = KNeighborsClassifier()
clf_B = SGDClassifier()
clf_C = BaggingClassifier()

results=get_results(clf_A, clf_B, clf_C, X_train_jc, y_train_jc, X_test_jc, y_test_jc)

# Run metrics visualization for the three supervised learning models chosen
evaluate(results, accuracy, fscore)
# Out:
# KNeighborsClassifier trained on 3538 samples.
# KNeighborsClassifier trained on 35389 samples.
# KNeighborsClassifier trained on 353892 samples.
# SGDClassifier trained on 3538 samples.
# SGDClassifier trained on 35389 samples.
# SGDClassifier trained on 353892 samples.
# BaggingClassifier trained on 3538 samples.
# BaggingClassifier trained on 35389 samples.
# BaggingClassifier trained on 353892 samples.
# C:\Users\PPawelec\AppData\Local\Temp\ipykernel_11568\1375473375.py:68: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
def evaluate(results, accuracy, f1):
    """
    Visualization code to display results of various learners.
    
    inputs:
      - learners: a list of supervised learners
      - stats: a list of dictionaries of the statistic results from 'train_predict()'
      - accuracy: The score for the naive predictor
      - f1: The score for the naive predictor
    """
  
    # Create figure
    fig, ax = plt.subplots(2, 3, figsize = (11,7))

    # Constants
    bar_width = 0.3
    colors = ['#A00000','#00A0A0','#00A000']
    
    # loop to plot six panels of data
    for k, learner in enumerate(results.keys()):
        for j, metric in enumerate(['train_time', 'acc_train', 'f_train', 'pred_time', 'acc_test', 'f_test']):
            for i in np.arange(3):
                
                # Creative plot code
                ax[j//3, j%3].bar(i+k*bar_width, results[learner][i][metric], width = bar_width, color = colors[k])
                ax[j//3, j%3].set_xticks([0.45, 1.45, 2.45])
                ax[j//3, j%3].set_xticklabels(["1%", "10%", "100%"])
                ax[j//3, j%3].set_xlabel("Training Set Size")
                ax[j//3, j%3].set_xlim((-0.1, 3.0))
    
    # Add unique y-labels
    ax[0, 0].set_ylabel("Time (in seconds)")
    ax[0, 1].set_ylabel("Accuracy Score")
    ax[0, 2].set_ylabel("F-score")
    ax[1, 0].set_ylabel("Time (in seconds)")
    ax[1, 1].set_ylabel("Accuracy Score")
    ax[1, 2].set_ylabel("F-score")
    
    # Add titles
    ax[0, 0].set_title("Model Training")
    ax[0, 1].set_title("Accuracy Score on Training Subset")
    ax[0, 2].set_title("F-score on Training Subset")
    ax[1, 0].set_title("Model Predicting")
    ax[1, 1].set_title("Accuracy Score on Testing Set")
    ax[1, 2].set_title("F-score on Testing Set")
    
    # Add horizontal lines for naive predictors
    ax[0, 1].axhline(y = accuracy, xmin = -0.1, xmax = 3.0, linewidth = 1, color = 'k', linestyle = 'dashed')
    ax[1, 1].axhline(y = accuracy, xmin = -0.1, xmax = 3.0, linewidth = 1, color = 'k', linestyle = 'dashed')
    ax[0, 2].axhline(y = f1, xmin = -0.1, xmax = 3.0, linewidth = 1, color = 'k', linestyle = 'dashed')
    ax[1, 2].axhline(y = f1, xmin = -0.1, xmax = 3.0, linewidth = 1, color = 'k', linestyle = 'dashed')
    
    # Set y-limits for score panels
    ax[0, 1].set_ylim((0, 1))
    ax[0, 2].set_ylim((0, 1))
    ax[1, 1].set_ylim((0, 1))
    ax[1, 2].set_ylim((0, 1))

    # Create patches for the legend
    patches = []
    for i, learner in enumerate(results.keys()):
        patches.append(mpatches.Patch(color = colors[i], label = learner))
    plt.legend(handles = patches, bbox_to_anchor = (-.80, 2.53), \
               loc = 'upper center', borderaxespad = 0., ncol = 3, fontsize = 'x-large')
    
    # Aesthetics
    plt.suptitle("Performance Metrics for Three Supervised Learning Models", fontsize = 16, y = 1.10)
    plt.tight_layout()
    plt.show()

# %%
from sklearn.metrics import fbeta_score, accuracy_score

def train_predict(learner, sample_size, X_train, y_train, X_test, y_test): 
    '''
    inputs:
       - learner: the learning algorithm to be trained and predicted on
       - sample_size: the size of samples (number) to be drawn from training set
       - X_train: features training set
       - y_train: user type training set
       - X_test: features testing set
       - y_test: user type testing set
    '''
    
    results = {}
    
    # Fit the learner to the training data
    start = time() # Get start time
    learner = learner.fit(X_train[:sample_size], y_train[:sample_size])
    end = time() # Get end time
    
    # Calculate the training time
    results['train_time'] = end - start
        
    # Get the predictions on the test set(X_test),
    #       then get predictions on the first 300 training samples(X_train) using .predict()
    start = time() # Get start time
    predictions_test = learner.predict(X_test)
    predictions_train = learner.predict(X_train[:300])
    end = time() # Get end time
    
    #Calculate the total prediction time
    results['pred_time'] = end - start
            
    #Compute accuracy on the first 300 training samples
    results['acc_train'] = accuracy_score(predictions_train, y_train[:300])
        
    # Compute accuracy on the test set
    results['acc_test'] = accuracy_score(predictions_test, y_test)
    
    # Compute F-score on the first 300 training samples
    results['f_train'] = fbeta_score(predictions_train, y_train[:300], beta=0.5)
        
    # Compute F-score on the test set
    results['f_test'] = fbeta_score(predictions_test, y_test, beta=0.5)
       
    # Success
    print("{} trained on {} samples.".format(learner.__class__.__name__, sample_size))
        
    # Return the results
    return results

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# Initialize the classifier
clf = RandomForestClassifier(random_state=25)

# create search parameters
parameters = {"n_estimators":[50, 100, 150], 
              "max_depth": [3, 5, 10, 15],
              "min_samples_split": range(2,6), 
              "min_samples_leaf": range(1,3), 
             }

# make an fbeta scorer
scorer = make_scorer(fbeta_score, beta=0.5)

# Perform grid search
grid_obj = GridSearchCV(clf, parameters, scoring=scorer)

# Fit the grid search object to the training data and find the optimal parameters
grid_fit = grid_obj.fit(X_train, y_train)

# Get the estimator
best_clf = grid_fit.best_estimator_

# Make predictions using the unoptimized model
predictions = (clf.fit(X_train, y_train)).predict(X_test)
best_predictions = best_clf.predict(X_test)

# Report the before-and-afterscores
print("Unoptimized model\n------")
print("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test, predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test, predictions, beta = 0.5)))
print("\nOptimized Model\n------")
print("Final accuracy score on the testing data: {:.4f}".format(accuracy_score(y_test, best_predictions)))
print("Final F-score on the testing data: {:.4f}".format(fbeta_score(y_test, best_predictions, beta = 0.5)))
# Out:
# Unoptimized model
# ------
# Accuracy score on testing data: 0.9700
# F-score on testing data: 0.9785
#
# Optimized Model
# ------
# Final accuracy score on the testing data: 0.9674
# Final F-score on the testing data: 0.9759

# %%
# Get the optimized parameters
print(grid_fit.best_params_)
# Out:
# {'max_depth': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 150}

# %%
# train a model with the optimized parameters
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import fbeta_score, accuracy_score
# initiate model
clf = RandomForestClassifier(max_depth= 15, min_samples_leaf= 1, min_samples_split= 2, n_estimators= 150)
clf.fit(X_train_ny, y_train_ny)
predictions=clf.predict(X_test_ny)

# print naive assumption and the results
print("Naive accurace score: {:.4f}".format(accuracy_ny))
print("Naive F-score: {:.4f}".format(fscore_ny))
print("Accuracy score on testing data: {:.4f}".format(accuracy_score(y_test_ny, predictions)))
print("F-score on testing data: {:.4f}".format(fbeta_score(y_test_ny, predictions, beta = 0.5)))
# Out:
# Naive accurace score: 0.8899
# Naive F-score: 0.9099
# Accuracy score on testing data: 0.9479
# F-score on testing data: 0.9610

# %%
from sklearn.ensemble import RandomForestClassifier
# initiate model
model = RandomForestClassifier(random_state=25).fit(X_train_jc, y_train_jc)
# get weights
importances = model.feature_importances_ 
# plot the five most important features
feature_plot(importances, X_train, y_train)

# %%
def feature_plot(importances, X_train, y_train):
    '''
    inputs:
       - importances: the feature weights
       - X_train: features training set
       - y_train: user type training set
    '''
    # Display the five most important features
    indices = np.argsort(importances)[::-1]
    columns = X_train.columns.values[indices[:5]]
    values = importances[indices][:5]

    # Create the plot
    fig = plt.figure(figsize = (18,5))
    plt.title("Normalized Weights for First Five Most Predictive Features", fontsize = 16)
    plt.bar(np.arange(10), values, width = 0.6, align="center", color = '#00A000', \
          label = "Feature Weight")
    plt.bar(np.arange(10) - 0.3, np.cumsum(values), width = 0.2, align = "center", color = '#00A0A0', \
          label = "Cumulative Feature Weight")
    plt.xticks(np.arange(10), columns)
    plt.xlim((-0.5, 4.5))
    plt.ylabel("Weight", fontsize = 12)
    plt.xlabel("Feature", fontsize = 12)
    
    plt.legend(loc = 'upper center')
    plt.tight_layout()
    plt.show()
